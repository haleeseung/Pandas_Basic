# %%
# !conda list | grep pandas
# Out:
# zsh:1: command not found: conda

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/seunghalee/Desktop/friend_list.csv')

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df.head()
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager

# %%
df.head(2)
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer

# %%
df.tail()
# Out:
#     name  age        job
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df.tail(3)
# Out:
#     name  age      job
# 3  Julia   40  dentist
# 4  Brian   45  manager
# 5  Chris   25   intern

# %%
df = pd.read_csv('/Users/seunghalee/Desktop/friend_list.txt')

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df = pd.read_csv('/Users/seunghalee/Desktop/friend_list_tab.txt')

# %%
df
# Out:
#          name\tage\tjob
# 0     John\t20\tstudent
# 1  Jenny\t30\tdeveloper
# 2     Nate\t30\tteacher
# 3    Julia\t40\tdentist
# 4    Brian\t45\tmanager
# 5     Chris\t25\tintern

# %%
df = pd.read_csv('/Users/seunghalee/Desktop/friend_list_tab.txt', delimiter= '\t')

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df = pd.read_csv('/Users/seunghalee/Desktop/friend_list_no_head.csv', header = None)

# %%
df
# Out:
#        0   1          2
# 0   John  20    student
# 1  Jenny  30  developer
# 2   Nate  30    teacher
# 3  Julia  40    dentist
# 4  Brian  45    manager
# 5  Chris  25     intern

# %%
df.columns = ['name', 'age', 'job']

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df = pd.read_csv('/Users/seunghalee/Desktop/friend_list_no_head.csv', header = None, names = ['name', 'age', 'job'])

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern
